# %%
import os

# %%
import osmnx as ox

# %%
home_dir = "D:/UMass/Fall20/520/project/"

# %%
G = ox.graph_from_place('Amherst, MA')

# %%
ox.plot_graph(G)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
type(G)
# Out:
# networkx.classes.multidigraph.MultiDiGraph

# %%
G.number_of_nodes()
# Out:
# 6202

# %%
G.number_of_edges()
# Out:
# 17108

# %%
G.

# %%
for i in G.adjacency():
    if i[0] == 66643538:
        print(i)
# Out:
# (66643538, {66656988: {0: {'osmid': 9057554, 'lanes': '2', 'name': 'The Boulders', 'highway': 'residential', 'width': '12.2', 'oneway': False, 'length': 106.224, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000019F9F100760>, 'grade': 0.006}}, 6655624009: {0: {'osmid': 9057554, 'lanes': '2', 'name': 'The Boulders', 'highway': 'residential', 'width': '12.2', 'oneway': False, 'length': 81.619, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000019F9F100A00>, 'grade': 0.005}}, 66736984: {0: {'osmid': 9058046, 'highway': 'service', 'service': 'parking_aisle', 'oneway': False, 'length': 128.916, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000019F9F100910>, 'grade': 0.003}}, 66649451: {0: {'osmid': 9058046, 'highway': 'service', 'service': 'parking_aisle', 'oneway': False, 'length': 49.449, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000019F9F100670>, 'grade': 0.007}}})

# %%
start_loc = (42.35042,-72.52712)
end_loc = (42.40791,-72.53425)

# %%
start = ox.get_nearest_node(G, start_loc)
end = ox.get_nearest_node(G, end_loc)

# %%
start
# Out:
# 66643538

# %%
short_route = ox.shortest_path(G, start, end, weight='ele')

# %%
short_route = ox.shortest_path(G, start, end, weight='length')

# %%
ox.plot_graph_route(G, short_route)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
home = ox.graph_from_address('158, The Boulders, Amherst, MA')

# %%
ox.plot.plot_figure_ground(G=home)
# Out:
# (<Figure size 576x576 with 1 Axes>, <AxesSubplot:>)

# %%
ox.elevation.add_node_elevations(G, "AIzaSyBQllgh-_DeFmp-zp7iOgP60WZxAdkPSw4", max_locations_per_batch=500)

# %%
ox.elevation.add_edge_grades(G, add_absolute=False)

# %%
G.nodes.data()[start]
# Out:
# {'y': 42.35076, 'x': -72.527387, 'osmid': 66643538, 'elevation': 49.805}

# %%
import pickle

# %%
with open(home_dir + "Amherst_graph_w_elevation.pickle", 'wb') as handle:
    pickle.dump(G, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
G.graph
# Out:
# {'created_date': '2020-11-06 18:00:15',
#  'created_with': 'OSMnx 0.16.1',
#  'crs': 'epsg:4326',
#  'simplified': True,
#  'streets_per_node': {61722375: 4,
#   64034994: 4,
#   64051059: 4,
#   64056078: 3,
#   64056114: 3,
#   64056709: 3,
#   64632575: 3,
#   66590548: 3,
#   66590780: 3,
#   66590882: 4,
#   66591055: 3,
#   66591082: 3,
#   66591107: 3,
#   66591232: 3,
#   66591361: 3,
#   66591540: 3,
#   66591711: 3,
#   66592175: 3,
#   66592376: 4,
#   66592667: 3,
#   66592882: 3,
#   66592890: 3,
#   66592962: 3,
#   66593105: 3,
#   66593243: 3,
#   66593421: 3,
#   66593461: 3,
#   66593498: 3,
#   66593700: 1,
#   66593838: 3,
#   66594270: 3,
#   66594502: 3,
#   66594615: 5,
#   66594671: 3,
#   66594687: 3,
#   66594823: 3,
#   66594924: 3,
#   66594997: 3,
#   66595208: 3,
#   66595460: 3,
#   66595632: 1,
#   66595909: 3,
#   66596396: 1,
#   66596566: 3,
#   66596886: 3,
#   66596965: 3,
#   66597099: 3,
#   66597142: 3,
#   66597402: 1,
#   66597423: 3,
# ...

# %%
G.graph.keys()
# Out:
# dict_keys(['created_date', 'created_with', 'crs', 'simplified', 'streets_per_node'])

# %%
G.adj
# Out:
# MultiAdjacencyView({61722375: {66765897: {0: {'osmid': 9057446, 'lanes': '2', 'name': 'Harris Mountain Road', 'highway': 'residential', 'width': '15.2', 'oneway': False, 'length': 99.806, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000019F9EBC8070>, 'grade': -0.005}}, 5261370529: {0: {'osmid': 422095256, 'name': 'Robert Frost Trail (Orange)', 'highway': 'footway', 'oneway': False, 'length': 126.434, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000019F9EBC8280>, 'grade': -0.004}}}, 64034994: {66642126: {0: {'osmid': 9058578, 'highway': 'service', 'oneway': False, 'length': 12.946000000000002, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000019F9E0A6A60>, 'grade': -0.043}}, 66775328: {0: {'osmid': 9058578, 'highway': 'service', 'oneway': False, 'length': 66.20100000000001, 'geometry': <shapely.geometry.linestring.LineString object at 0x0000019F9E0A6820>, 'grade': 0.015}}, 319882540: {0: {'osmid': 245206346, 'name': 'Amherst U
# ...

# %%
G.adjacency()

# %%
hash('Amherst, MA')
# Out:
# -1731792266042832310
